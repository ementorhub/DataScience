# %%
#Code nay hien tai dang thieu Other, va can than user co 2 mentor mentee khi dung contains

# %%
import scrapy
import pandas as pd

# %%
import requests

cookies = {
    'wordpress_sec_6ef7f7293198b3c0f850c97eb92e606b': 'tuankiet%7C1642562723%7CM2ntmj0T60CwI1SSPVns5ydvdbt2ZKVHJKnTHi8NU3b%7Ccedfd92d20b0fa92912a4320fb9ffae08631d81e11b9c0e7974d156b64031b46',
    '_ga': 'GA1.1.2138357637.1634886347',
    'wp-wpml_current_admin_language_d41d8cd98f00b204e9800998ecf8427e': 'vi',
    'PHPSESSID': 'pet69eo04gdefj6d8mql70g2t4',
    'wordpress_test_cookie': 'WP%20Cookie%20check',
    'wp-wpml_current_language': 'vi',
    '_ga_TZ0PQKEQSM': 'GS1.1.1642389920.92.0.1642389920.0',
    'wordpress_logged_in_6ef7f7293198b3c0f850c97eb92e606b': 'tuankiet%7C1642562723%7CM2ntmj0T60CwI1SSPVns5ydvdbt2ZKVHJKnTHi8NU3b%7C3c2d2fb4c1465d73d8858663e18de0c3729dc366792a5d1f275145e0bacb3e18',
    'wp-settings-187': 'libraryContent%3Dbrowse%26editor%3Dtinymce',
    'wp-settings-time-187': '1642389925',
    'AWSALB': 'IVrQo24WjQcsL2qg11Oq4XxpqhPRCTj4MqJ3S4LY9WxLtuOigEWq9zCsqSQc7MdtvTAOSu58qauCF/D1lJh6X4c78T2nrJeWI2I9EskrYskrsQ31sd92FEhsoSzK',
    'AWSALBCORS': 'IVrQo24WjQcsL2qg11Oq4XxpqhPRCTj4MqJ3S4LY9WxLtuOigEWq9zCsqSQc7MdtvTAOSu58qauCF/D1lJh6X4c78T2nrJeWI2I9EskrYskrsQ31sd92FEhsoSzK',
}

headers = {
    'authority': 'ementorhub.com',
    'cache-control': 'max-age=0',
    'sec-ch-ua': '" Not;A Brand";v="99", "Google Chrome";v="97", "Chromium";v="97"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'upgrade-insecure-requests': '1',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/97.0.4692.71 Safari/537.36',
    'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
    'sec-fetch-site': 'same-origin',
    'sec-fetch-mode': 'navigate',
    'sec-fetch-user': '?1',
    'sec-fetch-dest': 'document',
    'accept-language': 'en-US,en;q=0.9,vi-VN;q=0.8,vi;q=0.7',
}

# %%
def cleanSelector(obj, xpath = './text()'):
    clean_list = []
    for i in range(len(obj)):
        if obj[i].xpath(xpath).extract():
            clean_list.append(obj[i].xpath(xpath).extract()[0]) #wtheck is this :)) 
        else:
            clean_list.append(None)
    return clean_list

def getChecked(values, checks):
    output = []
    for value, check in zip(values, checks):
        if check == 'checked':
            output.append(value)
    if output:
        return output
    else:
        output = [None]
        return output

def list2text(thelist):
    text = thelist[0]
    if len(thelist) == 1:
        return text
    else:
        for i in range(1,len(thelist)):
            text = text + ', ' + thelist[i]
        return text

# %%
links = ['https://ementorhub.com/wp-admin/users.php',
         'https://ementorhub.com/wp-admin/users.php?paged=2',
         'https://ementorhub.com/wp-admin/users.php?paged=3',
         'https://ementorhub.com/wp-admin/users.php?paged=4',
         'https://ementorhub.com/wp-admin/users.php?paged=5',
       'https://ementorhub.com/wp-admin/users.php?paged=6']

# %%
data_dict = {'status': [],
            'prefix': [], #new
            'first name':[],
             'last name': [],
             'user': [],
            'mail': [],
            'link': [],
            'role': [],
             'Birth Date':[],
             'Phone code':[],
             'Phone':[],
             'Street Address':[],
             'Country':[],
             'State/Province':[],
             'City':[],
             'Postal/Zip Code':[],
             'Prefer communication': [], #new
             'Career status': [],
             'Year of working': [],
             'Job title': [],
             'Organization Name':[],
             'Industry user': [],
             'Other Industry': [],
             'LinkedIn profile link': [],
            'In 3-5 years': [],
            'The reason': [],
            'Who am I': [],
             'Ever mentoring?': [], #brandnew
             'Technical skill':[], #new
             'Soft skill': [], #new
            'Why would you make a good mentor': [],
            'Things you are expecting from a mentee': [],
            'what make good mentorship': [],
            'What do you expect to gain': [],
            'How many hours per month you want to be mentored': []}
count = 0

# %%
for link in links:
    response = requests.get(link, headers=headers, cookies=cookies).content
    sel = scrapy.Selector(text = response)
    users = cleanSelector(sel.xpath('//*[@id="the-list"]//strong/a'))
    mails = cleanSelector(sel.xpath('//*[@id="the-list"]//td[@class = "email column-email"]/a'))
    links = cleanSelector(sel.xpath('//*[@id="the-list"]//td[@class = "username column-username has-row-actions column-primary"]/strong/a'), './@href')
    roles = cleanSelector(sel.xpath('//*[@id="the-list"]//td[@class = "role column-role"]'))
    for i in range(len(users)):
        data_dict['user'].append(users[i])
        data_dict['mail'].append(mails[i])
        data_dict['link'].append(links[i])
        data_dict['role'].append(roles[i])
        if data_dict['role'][count] == "Administrator":
            data_dict['status'].append('Admin')
            
            data_dict['prefix'].append(None)
            data_dict['first name'].append(None)
            data_dict['last name'].append(None)
            data_dict['In 3-5 years'].append(None)
            data_dict['The reason'].append(None)
            data_dict['Who am I'].append(None)
            data_dict['Technical skill'].append(None)
            data_dict['Soft skill'].append(None)
            data_dict['Ever mentoring?'].append(None)
            
            data_dict['Birth Date'].append(None)
            data_dict['Phone code'].append(None)
            data_dict['Phone'].append(None)
            data_dict['Street Address'].append(None)
            data_dict['Country'].append(None)
            data_dict['State/Province'].append(None)
            data_dict['City'].append(None)
            data_dict['Postal/Zip Code'].append(None)
            data_dict['Prefer communication'].append(None) #new
            
            data_dict['Career status'].append(None)
            data_dict['Year of working'].append(None)
            data_dict['Job title'].append(None)
            data_dict['Organization Name'].append(None)
            data_dict['Industry user'].append(None)
            data_dict['Other Industry'].append(None)
            data_dict['LinkedIn profile link'].append(None)
            
            data_dict['Why would you make a good mentor'].append(None)
            data_dict['Things you are expecting from a mentee'].append(None)
            data_dict['what make good mentorship'].append(None)
            data_dict['What do you expect to gain'].append(None)
            data_dict['How many hours per month you want to be mentored'].append(None)
            print("Admin")
        elif data_dict['role'][count] == "Editor":
            data_dict['status'].append('Editor')
            
            data_dict['prefix'].append(None)
            data_dict['first name'].append(None)
            data_dict['last name'].append(None)
            data_dict['In 3-5 years'].append(None)
            data_dict['The reason'].append(None)
            data_dict['Who am I'].append(None)
            data_dict['Technical skill'].append(None)
            data_dict['Soft skill'].append(None)
            data_dict['Ever mentoring?'].append(None)
            
            data_dict['Birth Date'].append(None)
            data_dict['Phone code'].append(None)
            data_dict['Phone'].append(None)
            data_dict['Street Address'].append(None)
            data_dict['Country'].append(None)
            data_dict['State/Province'].append(None)
            data_dict['City'].append(None)
            data_dict['Postal/Zip Code'].append(None)
            data_dict['Prefer communication'].append(None) #new
            
            data_dict['Career status'].append(None)
            data_dict['Year of working'].append(None)
            data_dict['Job title'].append(None)
            data_dict['Organization Name'].append(None)
            data_dict['Industry user'].append(None)
            data_dict['Other Industry'].append(None)
            data_dict['LinkedIn profile link'].append(None)
            
            data_dict['Why would you make a good mentor'].append(None)
            data_dict['Things you are expecting from a mentee'].append(None)
            data_dict['what make good mentorship'].append(None)
            data_dict['What do you expect to gain'].append(None)
            data_dict['How many hours per month you want to be mentored'].append(None)
            print("Edit")
        else:
            res_detail = requests.get(links[i], headers=headers, cookies=cookies).content
            sel_detail = scrapy.Selector(text = res_detail)
            
            status = cleanSelector(sel_detail.xpath('//*[@id="wpseo_author_metadesc"]'))
            
            prefix = list2text(getChecked(cleanSelector(sel_detail.xpath('//*[@data-name="prefix_user"]//li//input'),
                                                        xpath = './@value'),
                                          cleanSelector(sel_detail.xpath('//*[@data-name="prefix_user"]//li//input'), 
                                                        xpath = './@checked')))
            
            info = cleanSelector(sel_detail.xpath('//*[contains(@data-name,"in_the_last_35_user")]//input'), './@value')
            reason = cleanSelector(sel_detail.xpath('//*[contains(@data-name,"what_i_like_about_user")]//input'), './@value')
            selfdef = cleanSelector(sel_detail.xpath('//*[@data-name="who_you_are_user"]//input'), './@value')
            firstname = cleanSelector(sel_detail.xpath('//*[@id="first_name"]'), './@value')
            lastname = cleanSelector(sel_detail.xpath('//*[@id="last_name"]'), './@value')
            
            technicalskill = list2text(getChecked(cleanSelector(sel_detail.xpath('//*[contains(@data-name,"technical_skills_user")]//li//input'),
                                                        xpath = './@value'),
                                          cleanSelector(sel_detail.xpath('//*[contains(@data-name,"technical_skills_user")]//li//input'), 
                                                        xpath = './@checked')))
            
            softskill = list2text(getChecked(cleanSelector(sel_detail.xpath('//*[contains(@data-name,"soft_skills_user")]//li//input'),
                                                        xpath = './@value'),
                                          cleanSelector(sel_detail.xpath('//*[contains(@data-name,"soft_skills_user")]//li//input'), 
                                                        xpath = './@checked')))
            
            mentoring = list2text(getChecked(cleanSelector(sel_detail.xpath('//*[contains(@data-name,"have_you_ever_mentored_user")]//li//input'),
                                                        xpath = './@value'),
                                          cleanSelector(sel_detail.xpath('//*[contains(@data-name,"have_you_ever_mentored_user")]//li//input'), 
                                                        xpath = './@checked')))
            
            birthday = cleanSelector(sel_detail.xpath('//*[@data-name="birth_date_user"]//input'), './@value')
            phonecode = cleanSelector(sel_detail.xpath('//*[@data-name="phone_code_user"]//input'), './@value')
            phone =cleanSelector(sel_detail.xpath('//*[@data-name="phone_user"]//input'), './@value')
            streetaddress = cleanSelector(sel_detail.xpath('//*[@data-name="address_user"]//input'), './@value')
            country =cleanSelector(sel_detail.xpath('//*[@data-name="country_user"]//input'), './@value')
            state = cleanSelector(sel_detail.xpath('//*[@data-name="state_user"]//input'), './@value')
            city = cleanSelector(sel_detail.xpath('//*[@data-name="city_user"]//input'), './@value')
            postal = cleanSelector(sel_detail.xpath('//*[@data-name="zipcode_user"]//input'), './@value')
            communication = list2text(getChecked(cleanSelector(sel_detail.xpath('//*[@data-name="how_would_you_prefer_user"]//li//input'),
                                                        xpath = './@value'),
                                          cleanSelector(sel_detail.xpath('//*[@data-name="how_would_you_prefer_user"]//li//input'), 
                                                        xpath = './@checked')))
            
            careerstatus = cleanSelector(sel_detail.xpath('//*[contains(@data-name,"career_status_user")]//input'), './@value')
            yearsofworking = cleanSelector(sel_detail.xpath('//*[contains(@data-name,"years_of_working_user")]//input'), './@value')
            jobtitle =cleanSelector(sel_detail.xpath('//*[contains(@data-name,"job_title_user")]//input'), './@value')
            organizationname = cleanSelector(sel_detail.xpath('//*[contains(@data-name,"organization_name_user")]//input'), './@value')
            industryuser = cleanSelector(sel_detail.xpath('//*[contains(@data-name,"industry_user")]//input'), './@value')
            otherindustry = cleanSelector(sel_detail.xpath('//*[contains(@data-name,"other_industry_user")]//input'), './@value')
            linkedin = cleanSelector(sel_detail.xpath('//*[contains(@data-name,"linkedin_profile_link_user")]//input'), './@value')
            
            info1 = cleanSelector(sel_detail.xpath('//*[contains(@data-name,"good_mentor_user")]//input'), './@value')
            info2 = cleanSelector(sel_detail.xpath('//*[contains(@data-name,"things_you_are_expecting_user")]//input'), './@value')
            info3 = cleanSelector(sel_detail.xpath('//*[contains(@data-name,"what_qualities_user")]//input'), './@value')
            info4 = cleanSelector(sel_detail.xpath('//*[contains(@data-name,"what_do_you_expect_user")]//input'), './@value')
            info5 = cleanSelector(sel_detail.xpath('//*[contains(@data-name,"update_mentor_many_hours_hidden")]//input'), './@value')
            
            print(status, prefix, communication, technicalskill, softskill, firstname, lastname, info, reason, "member", users[i])
            
            data_dict['status'].append(status[0])
            
            data_dict['prefix'].append(prefix)
            data_dict['In 3-5 years'].append(info[0])
            data_dict['The reason'].append(reason[0])
            data_dict['Who am I'].append(selfdef[0])
            data_dict['first name'].append(firstname[0])
            data_dict['last name'].append(lastname[0])
            data_dict['Technical skill'].append(technicalskill)
            data_dict['Soft skill'].append(softskill)
            data_dict['Ever mentoring?'].append(mentoring)
            
            data_dict['Birth Date'].append(birthday[0])
            data_dict['Phone code'].append(phonecode[0])
            data_dict['Phone'].append(phone[0])
            data_dict['Street Address'].append(streetaddress[0])
            data_dict['Country'].append(country[0])
            data_dict['State/Province'].append(state[0])
            data_dict['City'].append(city[0])
            data_dict['Postal/Zip Code'].append(postal[0])
            data_dict['Prefer communication'].append(communication) #new
            
            data_dict['Career status'].append(careerstatus[0])
            data_dict['Year of working'].append(yearsofworking[0])
            data_dict['Job title'].append(jobtitle[0])
            data_dict['Organization Name'].append(organizationname[0])
            data_dict['Industry user'].append(industryuser[0])
            data_dict['Other Industry'].append(otherindustry[0])
            data_dict['LinkedIn profile link'].append(linkedin[0])
            
            data_dict['Why would you make a good mentor'].append(info1[0])
            data_dict['Things you are expecting from a mentee'].append(info2[0])
            data_dict['what make good mentorship'].append(info3[0])
            data_dict['What do you expect to gain'].append(info4[0])
            data_dict['How many hours per month you want to be mentored'].append(info5[0])
        count += 1

df = pd.DataFrame(data_dict)

df.to_excel('FinalData.xlsx', index = True)
display(df)
# print(data_dict)
# Out:
# [None] mr Email None None [''] [''] [None] [None] member 18120256@student.hcmus.edu.vn
# [None] mr Email None None [''] [''] [None] [None] member ai17802.ai@gmail.com
# ['Updated'] mr Book meeting via eMentorHub Finance, Sales and Marketing, Other Career growth, Career switch, Decision-making, Listening, Negotiation, Networking, Problem-solving ['Alan'] ['Vo'] [None] ['I immigrated to a new country and switch my career to a very diferent industry and occupation.'] member alanvo1510@gmail.com
# [None] mr, mr Email, Email Other Career switch, Decision-making, Networking, Problem-solving ['Andrew'] ['Chou'] [None, None] [None, None] member andrew.yh.chou@gmail.com
# [None] mr Email None None [''] [''] [None] [None] member anguy012@uottawa.ca
# [None] mr Email None None [''] [''] [None] [None] member anh.nguyen@acs-aec.ca
# [None] mr Email None None [''] [''] [None] [None] member anhkiettran2602@gmail.com
# Admin
# ...
