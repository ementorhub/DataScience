# %%
import scrapy
import pandas as pd

# %%
import requests

cookies = {
    'wordpress_sec_6ef7f7293198b3c0f850c97eb92e606b': 'tuankiet%7C1638967546%7CPwMLwJja7RweqHSmQXdBplEnsJNgO721r4YA2LH8Meu%7Ce9514307d32b0b78691384b3eb4d470c2117483677c4e55745bcb7581e688fe8',
    '_ga': 'GA1.1.2138357637.1634886347',
    'accepted-cookie-policy': 'accepted',
    'PHPSESSID': 'fp57gb9rak181o8lik5iii3stq',
    'wp-wpml_current_language': 'en',
    'wordpress_test_cookie': 'WP%20Cookie%20check',
    '_ga_TZ0PQKEQSM': 'GS1.1.1638794731.49.1.1638794743.0',
    'wordpress_logged_in_6ef7f7293198b3c0f850c97eb92e606b': 'tuankiet%7C1638967546%7CPwMLwJja7RweqHSmQXdBplEnsJNgO721r4YA2LH8Meu%7C20735243d8b83d9ba0e87e3d87e676a7cbfdd7c2dd3e60b1b67761641ee51b2e',
    'wp-wpml_current_admin_language_d41d8cd98f00b204e9800998ecf8427e': 'vi',
    'wp-settings-time-187': '1638795277',
    'AWSALB': 'O+Yj+ANnxnveW+jF4YjaHbjBgdTIrheElxnPHY5vqbXhlXi8NH7Pllnw9uIHVpokEFn3mrfkX+YlhT89i0dAW7etkFXIE75A7fPXxxXRjyqOKDWsoXaT63rSJvS+',
    'AWSALBCORS': 'O+Yj+ANnxnveW+jF4YjaHbjBgdTIrheElxnPHY5vqbXhlXi8NH7Pllnw9uIHVpokEFn3mrfkX+YlhT89i0dAW7etkFXIE75A7fPXxxXRjyqOKDWsoXaT63rSJvS+',
}

headers = {
    'authority': 'ementorhub.com',
    'cache-control': 'max-age=0',
    'sec-ch-ua': '" Not A;Brand";v="99", "Chromium";v="96", "Google Chrome";v="96"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'upgrade-insecure-requests': '1',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.45 Safari/537.36',
    'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
    'sec-fetch-site': 'same-origin',
    'sec-fetch-mode': 'navigate',
    'sec-fetch-user': '?1',
    'sec-fetch-dest': 'document',
    'referer': 'https://ementorhub.com/wp-login.php?redirect_to=https%3A%2F%2Fementorhub.com%2Fwp-admin%2Fusers.php&reauth=1',
    'accept-language': 'en-US,en;q=0.9,vi-VN;q=0.8,vi;q=0.7',
}

# %%
def cleanSelector(obj, xpath = './text()'):
    clean_list = []
    for i in range(len(obj)):
        if obj[i].xpath(xpath).extract():
            clean_list.append(obj[i].xpath(xpath).extract()[0])
        else:
            clean_list.append(None)
    return clean_list

# %%
links = ['https://ementorhub.com/wp-admin/users.php',
         'https://ementorhub.com/wp-admin/users.php?paged=2',
         'https://ementorhub.com/wp-admin/users.php?paged=3',
         'https://ementorhub.com/wp-admin/users.php?paged=4',
         'https://ementorhub.com/wp-admin/users.php?paged=5']

# %%
data_dict = {'user': [],
            'mail': [],
            'link': [],
            'role': [],
            'In 3-5 years': [],
            'The reason': [],
            'Who am I': [],
            'Make a good role': [],
            'Expecting from other role': [],
            'good relationship':[],
            'Expecting to gain':[]}
count = 0

# %%
for link in links:
    response = requests.get(link, headers=headers, cookies=cookies).content
    sel = scrapy.Selector(text = response)
    users = cleanSelector(sel.xpath('//*[@id="the-list"]//strong/a'))
    mails = cleanSelector(sel.xpath('//*[@id="the-list"]//td[@class = "email column-email"]/a'))
    links = cleanSelector(sel.xpath('//*[@id="the-list"]//td[@class = "username column-username has-row-actions column-primary"]/strong/a'), './@href')
    roles = cleanSelector(sel.xpath('//*[@id="the-list"]//td[@class = "role column-role"]'))
    for i in range(len(users)):
        data_dict['user'].append(users[i])
        data_dict['mail'].append(mails[i])
        data_dict['link'].append(links[i])
        data_dict['role'].append(roles[i])
        if data_dict['role'][count] == "Administrator":
            data_dict['In 3-5 years'].append(None)
            data_dict['The reason'].append(None)
            data_dict['Who am I'].append(None)
            data_dict['Make a good role'].append(None)
            data_dict['Expecting from other role'].append(None)
            data_dict['good relationship'].append(None)
            data_dict['Expecting to gain'].append(None)
            print("Admin")
        elif data_dict['role'][count] == "Editor":
            data_dict['In 3-5 years'].append(None)
            data_dict['The reason'].append(None)
            data_dict['Who am I'].append(None)
            data_dict['Make a good role'].append(None)
            data_dict['Expecting from other role'].append(None)
            data_dict['good relationship'].append(None)
            data_dict['Expecting to gain'].append(None)
            print("Edit")
        else:
            res_detail = requests.get(links[i], headers=headers, cookies=cookies).content
            sel_detail = scrapy.Selector(text = res_detail)
            info = cleanSelector(sel_detail.xpath('//*[@id="your-profile"]/table[7]/tbody/tr[29]//input'), './@value')
            reason = cleanSelector(sel_detail.xpath('//*[@id="your-profile"]/table[7]/tbody/tr[30]//input'), './@value')
            selfdef = cleanSelector(sel_detail.xpath('//*[@id="your-profile"]/table[7]/tbody/tr[13]//input'), './@value')
            moreinfo1 = cleanSelector(sel_detail.xpath('//*[@id="your-profile"]/table[7]/tbody/tr[36]//input'), './@value')
            moreinfo2 = cleanSelector(sel_detail.xpath('//*[@id="your-profile"]/table[7]/tbody/tr[37]//input'), './@value')
            moreinfo3 = cleanSelector(sel_detail.xpath('//*[@id="your-profile"]/table[7]/tbody/tr[38]//input'), './@value')
            moreinfo4 = cleanSelector(sel_detail.xpath('//*[@id="your-profile"]/table[7]/tbody/tr[39]//input'), './@value')
            print(info, reason, selfdef, moreinfo1, moreinfo2, moreinfo3, moreinfo4, "men", users[i])
            data_dict['In 3-5 years'].append(info[0])
            data_dict['The reason'].append(reason[0])
            data_dict['Who am I'].append(selfdef[0])
            data_dict['Make a good role'].append(moreinfo1[0])
            data_dict['Expecting from other role'].append(moreinfo2[0])
            data_dict['good relationship'].append(moreinfo3[0])
            data_dict['Expecting to gain'].append(moreinfo4[0])
        count += 1

df = pd.DataFrame(data_dict)

df.to_excel('CustomerData.xlsx', index = True)
display(df)
# print(data_dict)
# Out:
# [None] [None] [None] [None] [None] [None] [None] men 18120256@student.hcmus.edu.vn
# [None] [None] [None] [None] [None] [None] [None] men ai17802.ai@gmail.com
# [None] [None] [None] [None] [None] [None] [None] men alanvo1510@gmail.com
# [None] [None] [None] [None] [None] [None] [None] men anguy012@uottawa.ca
# [None] [None] [None] [None] [None] [None] [None] men anh.nguyen@acs-aec.ca
# Admin
# [None] [None] [None] [None] [None] [None] [None] men baogia01022021@gmail.com
# ['coordinated a pilot project with Environics to improve data informed decision making at the City of Ottawa'] ['I have a chance to work with many talented people in the field of data science.'] [None] ['I listen'] ['A desire to learn'] ['Listening'] ["I'm not sure"] men bendick2@gmail.com
# [None] [None] [None] [None] [None] [None] [None] men bichtuyen84@gmail.com
# [None] [None] [None] [None] [None] [None] [None] men buiphuong362@gmail.com
# ['kỹ năng phân tích chuyên nghiệp, thành thạo công cụ phân tích'] ['Mong muốn theo đuổi ngành Data Analyst'] [None] ['1) Đam mê với nghề Data Analyst, nên sẽ cẩn thận và ham học hỏi từ các anh/chị đi trước. \n2) Đang làm công việc về dữ liệu (nhưng chưa chuyên sâu) nên sẽ học nghiêm túc, hoàn thành các giáo trình đưa ra để phát triển sự nghiệp\n3) Cũng là một người hướng đến cộng đồng, mong muốn chia sẻ kinh nghiệm, kiến thức. Vì thế, nếu mình có kinh nghiệm, mình cũng có đam mê để xây dựng cộng đồng lớn mạnh hơn vì ý nghĩa của dự án này mang lại.'] ['1) Hòa đồng, thân thiện (cái này mình biết anh/chị đã có sẵn rồi ^^ )\n2) Có kinh nghiệm thực tế (Cái này cũng có luôn rồi)\n3) Biết anh/chị rất bận, nhưng có thể trả lời email/call ít nhất 2 lần mỗi tuần.'] ['1) Trung thực\n2) Đúng giờ\n3) Hòa đồng, thân thiện\n4) Nhiệt tình từ 2 bên'] ['1) Học hỏi kinh nghiệm thực tiễn từ mentor\n2) Giúp mình củng cố kiến thức và cấu trúc để phát triển kỹ năng chuyên nghiệp\n3) Học được tinh thần mà mentor mang lại.'] men caothenguyen@outlook.com
# [None] [None] [None] [None] [None] [None] [None] men chitrung318@gmail.com
# ['chuyển công việc từ code sang tư vấn, đào tạo và quả lý.'] ['muốn có một công việc phù hợp, làm với tâm thế thoải mái, tự do và hạnh phúc hơn.'] [None] ['Tôi biết lắng nghe, nghiêm túc và lễ độ.'] ['Không manipulate và không bullying.'] ['Sự minh bạch và tôn trọng lẫn nhau.'] ['Học hỏi được nhiều kinh nghiệm thực tế.'] men congduyto@gmail.com
# [None] [None] [None] [None] [None] [None] [None] men conthomautim@gmail.com
# Admin
# ['vẫn là sinh viên'] ['đang đi học'] [None] ['không biết'] ['không biết'] ['chưa có'] ['chưa suy nghĩ đến'] men dkhn1201@gmail.com
# [None] [None] [None] ['Tôi cùng 1 người bạn đang khởi động 1 side project, dự án A Vậy Hả - Người thường khởi nghiệp (www.avayha.com), một dự án cộng đồng, tiến tới lợi nhuận trong tương lai, cung cấp kho chuyện khởi nghiệp gần gũi cho người kinh doanh nhỏ và siêu nhỏ tại VN.\n\nTôi đang làm việc toàn thời gian, nhưng rất nghiêm túc với dự án này. Tôi đã theo đuổi dự án 10 tháng từ đầu năm tới giờ. Tôi bỏ thời gian buổi tối và cuối tuần cho dự án. \n\nTôi rất ham học hỏi, và mong muốn có cơ hội được trao đổi với những người giỏi và có tâm. Hi vọng eMentorHub có thể kết nối với những cố vấn phù hợp. Xin cảm ơn các bạn.'] ['Dự án A Vậy Hả cũng tiến triển tốt, nhưng tôi muốn học hỏi thêm từ cố vấn của mình kinh nghiệm, và chiến lược làm sao đẩy nhanh về growth và marketing.'] ['Lắng nghe, thấu hiểu, tinh thần ham học hỏi và đối thoại.'] ['Tôi cùng 1 người bạn đang khởi động 1 side project, dự án A Vậy Hả - Người thường khởi nghiệp (www.avayha.com), một dự án cộng đồng, tiến tới lợi nhuận trong tương lai, cung cấp kho chuyện khởi nghiệp gần gũi cho người kinh doanh nhỏ và siêu nhỏ tại VN.\n\nDự án A Vậy Hả cũng tiến triển tốt, nhưng tôi muốn học hỏi thêm từ cố vấn của mình kinh nghiệm, và chiến lược làm sao đẩy nhanh về growth và marketing.'] men dlhson@gmail.com
# [None] [None] [None] [None] [None] [None] [None] men dohoangvienpr@gmail.com
# [None] [None] [None] [None] [None] [None] [None] men dungntp92@gmail.com
# [None] [None] [None] ['Tôi có kinh nghiệm giảng dạy và mentor ở công ty và ở Singapore'] ['Chăm chỉ, chịu khó, có nghị lực'] ['có chung sở thích, mục đích sống, mentee thích nghiên cứu, khám phá những điều mới mẻ'] ['Tôi mong muốn giúp đỡ các bạn trẻ có kinh nghiệm trong cuộc sống'] men duong.lequyqn@gmail.com
# [None] [None] [None] [None] [None] [None] [None] men duy.buibao@gmail.com
# Admin
# Admin
# [None] [None] [None] [None] [None] [None] [None] men gsthanhnguyen@gmail.com
# [None] [None] [None] [None] [None] [None] [None] men hanhan3295305@gmail.com.vn
# ['nguyện vọng được làm việc tại các tổ chức phi chính phủ với vai trò là người sáng tạo nội dung và truyền thông những thông điệp có ý nghĩa'] ['Đây là công việc hướng đến cộng đồng, được đi đến nhiều nơi và có nhiều trải nghiệm trong môi trường quốc tế.'] [None] ['Em không thể định nghĩa chính xác một mentee tốt là như thế nào nhưng em tin rằng thái độ ham học hỏi và tinh thần tự giác trong mọi hoạt động sẽ giúp bản thân em trở thành một mentee tốt và có thể phát triển bản thân trong tương lai.'] ['Thấu hiểu vấn đề, Truyền đạt tốt và Biết lắng nghe là ba tiêu chí em nghĩ những người cố vấn nên có'] ['Em nghĩ là cả hai nên bắt đầu từ sự mở lòng để sẻ chia, sau đó là thấu hiểu để có những chia sẻ đáp ứng với yêu cầu và nguyện vọng của cả hai bên.'] ['Em mong sau khi trao đổi, những khó khăn của bản thân sẽ được giải quyết và nếu người mentor có thể hướng em sang những con đường mới phù hợp với bản thân em thì quá tốt.'] men hanhieuhan@gmail.com
# [None] [None] [None] [None] [None] [None] [None] men hghblignz@gmail.com
# Admin
# ['worked in the high-level management position as CCO and Managing director for VMG and Lasluz'] ['I have chance to build the strategy and implement the plan from zero to 1 in educational field.'] [None] ['Listening and problem solving skills are my core strengths that made me a good mentor. In any case, I listen carefully about the problem and find out the root causes of it and then sketch out a detailed plan and direction that can solve the problem in the proper way.'] ['Curiosity and dynamic are the characteristics that I think will be benefit for the mentee. The mentee should ask questions and raise the problem that he/she cannot solve. In other way, a mentee should be active in helping mentor to find a good way to enhance and share their thoughts/experiences which are good for the mentee.'] ['Transparency, trust and sharing are the qualities that can help both mentor and mentee to build a good relationship. Additionally, mentee should stay connected with mentor in order to update and form a strong connection with each other.'] ['Happiness and Fulfillment. I love sharing and building people.'] men hoangphu.nguyen192@gmail.com
# ['cơ hội trải nghiệm những mảng khác nhau trong nghề Nhân Sự: Tuyển dụng, Đào tạo, Lương, Bảo hiểm...'] ['Tôi đã học được tính chủ động, tự học trong công việc nhiều hơn, đặc biệt với mỗi doanh nghiệp, tôi đều tự học và phát triển khả năng sử dụng các phần mềm quản lý nhân sự. Bên cạnh đó, việc có cơ hội làm trong môi trường Giáo dục là điều rất tốt, giúp tôi hoàn thiện nhân cách của bản thân từng ngày.'] [None] ['Vì mình muốn giúp Mentee nhận ra họ phù hợp với điều gì nhất, chứ không phải là làm theo điều họ thích nhất.'] ['Mình chắc chắn sẽ có vài điểm thiếu sót nhưng mình hy vọng sẽ giúp được họ phát triển theo chiều hướng tích cực, và sau này khi Mentee đã "cứng cáp", hãy giúp các Mentee khác nữa nhé.'] ['Trung thực, chân thành, lắng nghe, tôn trọng, tính cầu tiến.'] ['Mình được phát triển kỹ năng coaching, và mình sẽ tìm ra được kiến thức nào mình cần nên "lấp đầy" để chuẩn bị hỗ trợ cho các Mentee khác.'] men hongnga.hoang@gmail.com
# ['Công việc tôi yêu thích trong ngành nghề tôi được đào tạo.'] ['Tôi được cống hiến thời gian của mình để thiết kế các không gian công cộng cho cộng đồng.'] [None] ['Tôi có kinh nghiệm định cư, học tập và lập nghiệp tại Canada 8 năm nay.'] ['Ham học hỏi, nghiêm túc và tích cực và trung thực'] ['Cùng chí hướng, cùng quan điểm về nghề nghiệp, cởi mở và thân thiện.'] ['Giúp đỡ những bạn trẻ vững bước hơn trong quá trình học tập và lập nghiệp.'] men huong.giang.arch@gmail.com
# [None] [None] [None] [None] [None] [None] [None] men huongtrinh95nk@gmail.com
# ['Tôi đã đồng hành với nhiều bạn sinh viên mới ra trường trên đường sự nghiệp, vận hành Beeteam hiệu quả.'] ['Đi du lịch để viết ký sự và chia sẻ với mọi người về phát triển bản thân'] [None] ['Bởi vì tôi có khả năng lắng nghe, chia sẻ một cách cởi mở. Tôi không áp đặt nhưng gợi ý những con đường để me tee tự chọn cho mong muốn của mình.Bên cạnh đó tôi được đánh giá là người có khả năng truyền cảm hứng. Cụ thể khi ai đó gặp tôi, họ dễ dàng có được thêm động lựcHơn thế tôi mong muốn làm tất cả để con đường của me tê được tốt hơn'] ['Tôi hi vọng các bạn cởi mở, nói ra hết tâm tư nguyện vọng của mình. Có thể chia sẻ những ưu tư, cùng với mentor đưa ra một hành trình phù hợp.Người mentor chỉ là ngọn đuốc. Chính các bạn phải tự đi, tự nghiệm, và tự thay đổi chính mình mỗi ngày.'] ['- Biết lắng nghe đối thoại- Cởi mở, tôn trọng- cẩn mật- Kế hoạch cho hành trình mentoringMentor và mentee phải giữ liên lạc, phải có kế hoạch cho các cuộc trao đổi. Qua đó sẽ từng bước đạt mục tiêu của cuộc mentoring.Người mentor và mentee phải thông hiểu lẫn nhau.'] ['Tôi muốn ngày càng quen với nhiều người hơn, có thể trao đổi với nhiều người hơn. Qua đó tôi hiểu sâu hơn từng tính cạch, giúp tăng vốn văn hóa của bản thân, trong lĩnh vực tương tác với con ngườiVà đặc biệt là sự chia sẻ, lan tỏa thông điệp tích cực đến mọi người'] men Huuquilx@gmail.com
# [None] [None] [None] [None] [None] [None] [None] men igor.kozlov@mail.mcgill.ca
# Admin
# [None] [None] [None] [None] [None] [None] [None] men jay_freeman89@yahoo.com
# ['Tôi giúp các công ty mình làm việc phát triển rất nhanh về khách hàng và đối tác'] ['giúp được khách hàng đạt được mục tiêu đề ra'] [None] ['Mentoring là một quá trình phát triển theo giai đoạn giống như tập thể thao. Mentee cần được hướng dẫn đúng hướng và áp dụng nhiều cách khác nhau để vượt qua vấn đề đó. Vấn đề mà một mình mentee không thể làm được. Nhiệm vụ của mentor giống như người hướng dẫn, việc có thành công hay không thì mentor chỉ giúp 50%, 50% còn lại là nỗ lực của mentee.'] ['1) Mạnh dạn chia sẽ khó khăn\n2) Chủ động gặp mentor và chủ động gặp mentor khác trong các buổi mentoring\n3) Chủ động cập nhật cho mentor tình hình phát triển\n4) Chia sẽ thành công với mentee khác'] ['Việc gì cũng phải đến từ 2 phía, theo tôi tiêu chí để có mối quan hệ tốt đẹp giữa mentor và mentee là:\n1) Chia sẽ chân thành: giữa mentor và mentee. Điều gì xuất phát từ trái tim sẽ đến được tới trái tim.\n2) Mindset: mentee cần hiểu mentor không phải thần thánh, việc gì cũng biết hết. Vì vậy, khi hỏi mentor 1 việc nào đó mentor không rành thì mentor sẽ giới thiệu mentee đến 1 mentor chuyên về mảng mentee muốn hỗ trợ.\n3) Lòng biết ơn: khi mentee thành công rồi, ngoài việc cám ơn mentor và chương trình. Mentee cố gắng giữ liên lạc với mentor càng lâu càng tốt.'] ['1) Giúp được nhiều mentee\n2) Mở rộng quan hệ với mentor khác\n3) Cùng eMentorHub phát triển và chia sẽ nhiều câu chuyện thành công của mentee.'] men kevin.khoinguyen@gmail.com
# Admin
# [None] [None] [None] [None] [None] [None] [None] men kimthanh@canhcam.vn
# [None] [None] [None] [None] [None] [None] [None] men lamky08@gmail.com
# [None] [None] [None] [None] [None] [None] [None] men lamky78@gmail.com
# [None] [None] [None] [None] [None] [None] [None] men lenadinh@gmail.com
# [None] [None] [None] [None] [None] [None] [None] men lephuonguyen0305@gmail.com
# ['5 năm kinh nghiệm làm Business Development và tôi muốn trở thành chuyên gia về phân tích dữ liệu.'] ['Trong quá trình làm BD, tôi thường xuyên phân tích data để ra những quyết định và chiến lược, và từ đó tôi thấy sẽ giải quyết được nhiều pain point trong doanh nghiệp nếu kết hợp business knowledge và data analyst nên tôi muốn chuyển hẳn sang lĩnh vực Data Analyst.'] [None] ['Xin chào Mentor tương lai, mình là người làm Business Development ở mảng Ecommerce được 5 năm. Trong quá trình làm việc tại AhaMove - là một on-demand delivery platform, cơ sở dữ liệu ở đây khá open nên mặc dù là BD, mình tự query lấy data và phân tích để ra những quyết định hoặc chiến lược, điều đó cực kỳ hiệu quả và đã giúp mình đạt được một số thành tựu nhất định trong công việc BD. Từ đó mình bắt đầu tìm hiểu sâu hơn nữa về Data Analyst, nhờ vậy mình biết đến chương trình của EmentorHub, hy vọng mình có thể tìm được Mentor định hướng trong lĩnh vực này. Mình có khả năng tự học tốt, thái độ cầu tiến, có động lực rõ ràng nên mình tin rằng mình sẽ là một mentee tốt. Ngoài ra, mình còn có mindset và kiến thức về Ecommerce, hy vọng mình sẽ hỗ trợ được mentor trong khả năng, lĩnh vực mình biết và đồng hành cùng nhau không chỉ trong khuôn khổ chương trình này.'] ['Mình rất mong Mentor có thể định hướng lộ trình hoặc keyword về việc làm thế nào để phát triển sự nghiệp và trở thành một nhà phân tích tốt.'] ['Mối quan hệ tốt đối với mình là mối quan hệ win - win, để có được điều này, theo ý kiến cá nhân mình thì cần cả mentee và mentor đều đặt tâm vào và làm tốt vai trò của mỗi người. Ngoài ra, Mentor và Mentee cần align trước về kỳ vọng, quan điểm, cách làm việc, kết quả cần đạt.... để quá trình mentor diễn ra suôn sẻ.'] ['Mình hy vọng Mentor có thể xác định được lộ trình dựa theo kỳ vọng của Mentee, từ đó xác định Mentee đang ở đâu trên lộ trình và định hướng Mentee cần làm gì tiếp theo.'] men lh.ngocthach@gmail.com
# ['muốn trở thành một chuyên gia tư vấn trong lĩnh vực xây dựng thương hiệu.'] ['Tôi hứng thú với những giá trị cốt lõi mà một doanh nghiệp mang đến cho người dùng, xã hội thông qua nhiều phương thức tiếp cận khác nhau.'] [None] ['Tôi luôn lắng nghe tích cực và tiếp thu những ý kiến đóng góp. Ngoài ra, tôi sẽ chủ động trong việc phát triển, thay đổi và cải thiện bản thân tiến bộ hơn sau những giờ tư vấn quý báu với mentor.'] ['Tôi mong muốn người cố vấn của mình đã có độ chín nhất định trong sự nghiệp, và ổn định cân bằng trong đời sống tinh thần.'] ['Chân thành, cởi mở và hiểu bản thân mình'] ['Có được bức tranh rõ ràng hơn về con đường phát triển sự nghiệp. Có một sân chơi để thiết lập nhiều mối quan hệ cùng phát triển.'] men maiq8919@gmail.com
# [None] [None] [None] [None] [None] [None] [None]
gmail.com
# [None] [None] [None] [None] [None] [None] [None] men nguyentronghieu702@gmail.com
# Admin
# [None] [None] [None] [None] [None] [None] [None] men nhungnhung201@gmail.com
# [None] [None] [None] ['tôi là 1 người làm việc theo tiêu chuẩn, biết phân tích và giải quyết vấn đề rất gọn gàng. Nhưng chưa có kiến thức về ngành nhiều'] ['Hiểu rõ về data science và machine learning, định hướng các vị trí làm về data science và machien learning. Cách chuyển từ sản xuất qua data science và machine learning'] ['biết lắng nghe, ham học hỏi, nhiệt tình, giúp đỡ lẫn nhau trong công việc'] ['nâng cao kiến thức về data science và machine learning'] men noname201244@gmail.com
# [None] [None] [None] [None] [None] [None] [None] men ntqchau@gmail.com
# [None] [None] [None] [None] [None] [None] [None] men phamhong.vmg@gmail.com
# [None] ['#'] [None] ['#'] ['#'] ['#'] ['#'] men phamtam.tn@gmail.com
# ['Trong 3-5 năm tới, tôi muốn chuyển công việc của tôi từ một nhà nghiên cứu sang một nhà phân tích kinh doanh.'] ['Như tôi biết, các nhà phân tích kinh doanh thường được trả lương cao hơn các nhà nghiên cứu.'] [None] ['Tôi hiểu rõ rằng tôi cam kết dành một giờ mỗi tháng trong thời gian 3 tháng sau khi được kết nối.\nTôi muốn hồ sơ của mình được giới thiệu trên website eMentorHub và các kênh truyền thông xã hội.'] ['Tôi hiểu rõ rằng tôi cam kết dành một giờ mỗi tháng trong thời gian 3 tháng sau khi được kết nối.\nTôi muốn hồ sơ của mình được giới thiệu trên website eMentorHub và các kênh truyền thông xã hội.'] ['Tôi hiểu rõ rằng tôi cam kết dành một giờ mỗi tháng trong thời gian 3 tháng sau khi được kết nối.\nTôi muốn hồ sơ của mình được giới thiệu trên website eMentorHub và các kênh truyền thông xã hội.'] ['Tôi hiểu rõ rằng tôi cam kết dành một giờ mỗi tháng trong thời gian 3 tháng sau khi được kết nối.\nTôi muốn hồ sơ của mình được giới thiệu trên website eMentorHub và các kênh truyền thông xã hội.'] men phanhuudinh@hotmail.com
# [None] [None] [None] [None] [None] [None] [None] men phongnguyen.learning@gmail.com
# [None] [None] [None] [None] [None] [None] [None] men phungnguyen1594@gmail.com
# [None] [None] [None] [None] [None] [None] [None] men phuonganh.2x2g@gmail.com
# Edit
# ['Tôi lead 1 team 65 members ở 4 quốc gia phát triển hệ thống loyalty và logistics được coi là business backbone systems cho phía đối tác.'] ['Tôi gặp và làm việc với nhiều bạn executive ở các công ty đa quốc gia để học hỏi thêm và cũng gặp với nhiều bạn freshers và giúp đỡ về định hướng cho các bạn trong công việc'] [None] ['Kĩ năng tôi trau dồi nhiều nhất ngoài công việc chuyên môn trong hơn 10 năm làm việc là lắng nghe và truyền đạt kinh nghiệm'] ['Một mentee cầu thị và mong muốn phát triển đúng hướng.'] ['Clear expectations.\nCommunication.\nCollaboration.'] ['Phát triển mạng lưới đối tác trong công việc.'] men phuongnamhoang@hotmail.com
# [None] [None] [None] [None] [None] [None] [None] men phuongstuff@gmail.com
em mong muốn là mentee nghiêm túc với quá trình mentor . Tức là bạn thực sự nghiêm túc muốn tìm hiểu và sẵn sàng lắng nghe là được ạ .'] ['Em nghĩ đấy là sự quan tâm và thấu hiểu. Mentor cần phải thực sự quan tâm đến mentee và cố gắng hiểu mentee thì mới có thể đưa ra những gợi ý/ lời khuyên phù hợp với mentee được. Ở chiều hướng ngược lại, em nghĩ mentee cần có sự tôn trọng cho mentor và thời gian mà mentor dành cho mentee ạ.'] ['Em muốn có những trải nghiệm mới, gặp được những con người thú vị.'] men vu.q.dam@gmail.com
# [None] [None] [None] [None] [None] [None] [None] men wearethesame@gmail.com
# [None] [None] [None] [None] [None] [None] [None] men wearethesame13@gmail.com
# Admin
#                              user                           mail  \
# 0   18120256@student.hcmus.edu.vn  18120256@student.hcmus.edu.vn
# 1            ai17802.ai@gmail.com           ai17802.ai@gmail.com
# 2            alanvo1510@gmail.com           alanvo1510@gmail.com
# 3             anguy012@uottawa.ca            anguy012@uottawa.ca
# 4           anh.nguyen@acs-aec.ca          anh.nguyen@acs-aec.ca
# ..                            ...                            ...
# 89     tuyetnhungspring@gmail.com     tuyetnhungspring@gmail.com
# 90             vu.q.dam@gmail.com             vu.q.dam@gmail.com
# 91         wearethesame@gmail.com                           None
# 92       wearethesame13@gmail.com       wearethesame13@gmail.com
# 93                       webadmin            lamky0708@gmail.com
#
#                                                  link           role  \
# 0   https://ementorhub.com/wp-admin/user-edit.php?...         Mentee
# 1   https://ementorhub.com/wp-admin/user-edit.php?...         Mentee
# 2   https://ementorhub.com/wp-admin/user-edit.php?...         Mentor
# 3   https://ementorhub.com/wp-admin/user-edit.php?...         Mentee
# 4   https://ementorhub.com/wp-admin/user-edit.php?...         Mentor
# ..                                                ...            ...
# 89  https://ementorhub.com/wp-admin/user-edit.php?...         Mentor
# 90  https://ementorhub.com/wp-admin/user-edit.php?...         Mentor
# 91  https://ementorhub.com/wp-admin/user-edit.php?...         Mentee
# 92  https://ementorhub.com/wp-admin/user-edit.php?...         Mentee
# 93  https://ementorhub.com/wp-admin/user-edit.php?...  Administrator
#
#                                          In 3-5 years  \
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# ..                                                ...
# 89                                               None
# 90  đã làm việc với những vị trí liên quan đến Dat...
# 91                                               None
# 92                                               None
# 93                                               None
#
#                                            The reason Who am I  \
# 0                                                None     None
# 1                                                None     None
# 2                                                None     None
# 3                                                None     None
# 4                                                None     None
# ..                                                ...      ...
# 89                                               None     None
# 90  tôi học được rất nhiều về Data và gặp được rất...     None
# 91                                               None     None
# 92                                               None     None
# 93                                               None     None
#
#                                      Make a good role  \
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# ..                                                ...
# 89                                               None
# 90  Em thích và thoải mái chia sẻ kinh nghiệm của ...
# 91                                               None
# 92                                               None
# 93                                               None
#
#                             Expecting from other role  \
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# ..                                                ...
# 89                                               None
# 90  Em mong muốn là mentee nghiêm túc với quá trìn...
# 91                                               None
# 92                                               None
# 93                                               None
#
#                                     good relationship  \
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# ..                                                ...
# 89                                               None
# 90  Em nghĩ đấy là sự quan tâm và thấu hiểu. Mento...
# 91                                               None
# 92                                               None
# 93                                               None
#
#                                     Expecting to gain
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# ..                                                ...
# 89                                               None
# 90  Em muốn có những trải nghiệm mới, gặp được nhữ...
# 91                                               None
# 92                                               None
# 93                                               None
#
# [94 rows x 11 columns]
