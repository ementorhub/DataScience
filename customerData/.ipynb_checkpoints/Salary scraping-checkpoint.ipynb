NB. Original query string below. It seems impossible to parse and
#reproduce query strings 100% accurately so the one below is given
#in case the reproduced version is not "correct".
# response = requests.get('https://www.glassdoor.ca/Salaries/ho-chi-minh-city-data-analyst-salary-SRCH_IL.0,16_IM1746_KO17,29.htm?clickSource=searchBtn', headers=headers)

# %%
import scrapy
import pandas as pd

# %%
def cleanSelector(obj, xpath = './text()'):
    clean_list = []
    for i in range(len(obj)):
        if obj[i].xpath(xpath).extract():
            clean_list.append(obj[i].xpath(xpath).extract()[0]) #wtheck is this :)) 
        else:
            clean_list.append(None)
    return clean_list

def getChecked(values, checks):
    output = []
    for value, check in zip(values, checks):
        if check == 'checked':
            output.append(value)
    if output:
        return output
    else:
        output = [None]
        return output

def list2text(thelist):
    text = thelist[0]
    if len(thelist) == 1:
        return text
    else:
        for i in range(1,len(thelist)):
            text = text + ', ' + thelist[i]
        return text

# %%
data_dict = {'Company': [],
            'Job': [],
            'Salary':[]}

# %%
urls_HCM = ['https://www.glassdoor.ca/Salaries/ho-chi-minh-city-data-analyst-salary-SRCH_IL.0,16_IM1746_KO17,29.htm',
        'https://www.glassdoor.ca/Salaries/ho-chi-minh-city-data-analyst-salary-SRCH_IL.0,16_IM1746_KO17,29_IP2.htm',
       'https://www.glassdoor.ca/Salaries/ho-chi-minh-city-data-analyst-salary-SRCH_IL.0,16_IM1746_KO17,29_IP3.htm',
       'https://www.glassdoor.ca/Salaries/ho-chi-minh-city-data-analyst-salary-SRCH_IL.0,16_IM1746_KO17,29_IP4.htm',
       'https://www.glassdoor.ca/Salaries/ho-chi-minh-city-data-analyst-salary-SRCH_IL.0,16_IM1746_KO17,29_IP5.htm']

urls_HN = ['https://www.glassdoor.ca/Salaries/hanoi-data-analyst-salary-SRCH_IL.0,5_IM1055_KO6,18.htm',
          'https://www.glassdoor.ca/Salaries/hanoi-data-analyst-salary-SRCH_IL.0,5_IM1055_KO6,18_IP2.htm',
          'https://www.glassdoor.ca/Salaries/hanoi-data-analyst-salary-SRCH_IL.0,5_IM1055_KO6,18_IP3.htm']

# %%
for url in urls_HCM:
    response = requests.get(url, headers=headers, params=params)
    response = response.content
    sel = scrapy.Selector(text = response)

    company = cleanSelector(sel.xpath('//*[contains(@data-test,"employer-name")]/a'))
    job = cleanSelector(sel.xpath('//span[contains(@data-test,"job-title")]'))
    salary = cleanSelector(sel.xpath('//*[contains(@data-test,"salary-info")]/h3'))
    print(company, job, salary)
    for i in range(len(company)):
        data_dict['Company'].append(company[i])
        data_dict['Job'].append(job[i])
        data_dict['Salary'].append(salary[i])
# Out:
# ['Sendo.vn', 'Profectus Group', 'VNG', 'VPB Finance', 'FPT Software', 'FPT Software', 'PwC', 'Shopee', 'Intel Corporation', 'EMPLOYERS', 'Tiki.vn', 'Tiki.vn', 'Nielsen', 'Lazada', 'Freelancer', 'FPT', 'JobHopin', 'IBM', 'Vietnam International Bank', 'MOMO (Vietnam)'] ['Data Analyst - Monthly', 'Data Analyst - Monthly', 'Data Analyst - Monthly', 'Data Analyst - Monthly', 'Data Analyst - Monthly Intern', 'Data Analyst - Monthly', 'Data Analyst - Monthly', 'Data Analyst - Monthly', 'Data Analyst - Monthly Intern', 'Data Analyst - Monthly', 'Data Analyst - Monthly Intern', 'Data Analyst - Monthly', 'Data Analyst', 'Data Analyst - Monthly Intern', 'Data Analyst - Monthly', 'Data Analyst - Monthly Intern', 'Data Analyst - Monthly', 'Data Analyst - Monthly', 'Data Analyst - Monthly', 'Data Analyst - Intern'] ['₫14,500,000', '₫11,000,000', '₫8M', '₫17M', '₫4M', '₫18M', '₫15M', '₫13M', '₫3M', '₫17M', '₫5M', '₫7M', '₫193M', '₫1M', '₫19M', '₫5M', '₫20M', '₫5M', '₫24M', '₫5M']
# ['Vnuhcm', 'SGS', 'Buzzmetrics', 'AIA', 'Dai-ichi Mutual Life', 'Business Analysts', 'Cho Tot', 'Officience', 'Tyme Digital', 'Sentifi', 'Trans Cosmos', 'World Export', 'RTA', 'Georgia Tech', 'Tableau Software', 'Kerry Express', 'YOOSE', 'A', 'Software Solutions Inc. (Dayton, OH)', 'Sai Gon Dep'] ['Data Analyst - Monthly Intern', 'Data Analyst', 'Data Analyst - Monthly', 'Data Analyst - Monthly', 'Data Analyst - Monthly Intern', 'Data Analyst - Monthly Intern', 'Data Analyst - Monthly', 'Data Analyst - Monthly', 'Data Analyst - Monthly Intern', 'Data Analyst - Monthly', 'Data Analyst - Monthly', 'Data Analyst - Monthly', 'Data Analyst - Monthly', 'Data Analyst - Monthly', 'Data Analyst - Monthly Intern', 'Data Analyst - Monthly', 'Data Analyst - Monthly', 'Data Analyst', 'Data Analyst', 'Data Analyst'] ['₫4M', '₫151M', '₫8M', '₫19M', '₫2M', '₫3M', '₫19M', '₫8M', '₫5M', '₫29M', '₫10M', '₫3M', '₫4M', '₫9M', '₫2M', '₫12M', '₫18M', '₫116M', '₫191M', '₫114M']
# ['K System', 'Senspark', 'CRIF', 'VNG', 'FPT Software', 'Tiki.vn', 'Knorex', 'Nielsen', 'Other', 'Home Credit International', 'Homecredit', 'PropertyGuru Group', 'Grab', 'Gojek', 'Officience', 'Vietlink Advertising', 'Vietlink Advertising', 'FPT', 'Knorex', 'Home Credit International'] ['Data Analyst - Monthly', 'Data Analyst - Monthly', 'Data Analyst - Monthly', 'Data Scientist - Monthly', 'Data Engineer - Monthly', 'Data Engineer - Monthly', 'Data Scientist - Monthly', 'Senior Data Analyst - Monthly', 'Senior Data Analyst - Monthly', 'Senior Data Analyst', 'Senior Data Analyst - Monthly', 'Senior Data Analyst - Monthly', 'Junior Data Analyst - Monthly', 'Junior Data Analyst - Monthly', 'Junior Data Analyst - Monthly', 'Junior Data Analyst', 'Junior Data Analyst - Monthly', 'Data Scientist - Monthly', 'Data Scientist - Monthly Intern', 'Data Scientist - Monthly'] ['₫10M', '₫8M', '₫10M', '₫19,550,000', '₫18,000,000', '₫40,000,000', '₫19M', '₫18M', '₫14M', '₫27M', '₫17M', '₫50M', '₫24M', '₫4M', '₫9M', '€43K', '₫24M', '₫24M', '₫7M', '₫19M']
# ['FPT Information System', 'BAEMIN Vietnam', 'Inspectorio', 'Sentifi', 'Timo (Vietnam)', 'LOGIVAN', 'BioTuring', 'momo', 'AlphaGroup', 'Hash Consulting Grp', 'Viettel Cyberspace Center', 'Real-Time Analytics', 'FPT', 'Home Credit International', 'Zalora', 'Athena Studio', 'WeVenture', 'Just Analytics', 'DLV Roofing & Exteriors', 'Antsomi'] ['Data Scientist - Monthly Intern', 'Data Scientist - Monthly', 'Data Scientist - Monthly', 'Data Scientist - Monthly', 'Data Scientist - Monthly', 'Data Scientist - Monthly', 'Data Scientist - Monthly Intern', 'Data Scientist', 'Data Scientist - Monthly', 'Data Scientist - Monthly', 'Marketing Data Analyst - Monthly', 'Lead Data Analyst - Monthly', 'Data Science - Intern', 'Data Engineer - Monthly', 'Data Engineer - Monthly', 'Data Engineer - Monthly', 'Data Engineer - Monthly', 'Data Engineer - Monthly', 'Data Engineer - Monthly', 'Data Engineer - Monthly'] ['₫8M', '₫53M', '₫92M', '₫23M', '₫19M', '₫13M', '₫10M', '₫10M', '₫10M', '₫22M', '₫17M', '₫24M', '₫14M', '₫29M', '₫22M', '₫19M', '₫14M', '₫12M', '₫29M', '₫15M']
# ['Meete.co', 'Miti (Vietnam)', 'FPT Software', 'Kyanon Digital', 'The Coca-Cola Company', 'Knorex', 'Tiki.vn'] ['Data Engineer - Monthly', 'Data Engineer - Monthly', 'Junior Data Scientist - Monthly', 'Junior Data Scientist - Monthly', 'Data Entry Clerk - Monthly', 'Associate Data Scientist - Monthly', 'Data Specialist - Monthly'] ['₫10M', '₫9M', '₫17M', '₫15M', '₫8M', '₫18M', '₫14M']

# %%
df = pd.DataFrame(data_dict)
df.to_excel('HCMSalary.xlsx', index = True)
display(data_dict)
# Out:
# {'Company': ['Sendo.vn',
#   'Profectus Group',
#   'VNG',
#   'VPB Finance',
#   'FPT Software',
#   'FPT Software',
#   'PwC',
#   'Shopee',
#   'Intel Corporation',
#   'EMPLOYERS',
#   'Tiki.vn',
#   'Tiki.vn',
#   'Nielsen',
#   'Lazada',
#   'Freelancer',
#   'FPT',
#   'JobHopin',
#   'IBM',
#   'Vietnam International Bank',
#   'MOMO (Vietnam)',
#   'Vnuhcm',
#   'SGS',
#   'Buzzmetrics',
#   'AIA',
#   'Dai-ichi Mutual Life',
#   'Business Analysts',
#   'Cho Tot',
#   'Officience',
#   'Tyme Digital',
#   'Sentifi',
#   'Trans Cosmos',
#   'World Export',
#   'RTA',
#   'Georgia Tech',
#   'Tableau Software',
#   'Kerry Express',
#   'YOOSE',
#   'A',
#   'Software Solutions Inc. (Dayton, OH)',
#   'Sai Gon Dep',
#   'K System',
#   'Senspark',
#   'CRIF',
#   'VNG',
#   'FPT Software',
#   'Tiki.vn',
#   'Knorex',
#   'Nielsen',
#   'Other',
#   'Home Credit International',
#   'Homecredit',
#   'PropertyGuru Group',
#   'Grab',
#   'Gojek',
#   'Officience',
#   'Vietlink Advertising',
#   'Vietlink Advertising',
#   'FPT',
#   'Knorex',
#   'Home Credit International',
#   'FPT Information System',
#   'BAEMIN Vietnam',
#   'Inspectorio',
#   'Sentifi',
#   'Timo (Vietnam)',
#   'LOGIVAN',
#   'BioTuring',
#   'momo',
#   'AlphaGroup',
#   'Hash Consulting Grp',
#   'Viettel Cyberspace Center',
#   'Real-Time Analytics',
#   'FPT',
#   'Home Credit International',
#   'Zalora',
#   'Athena Studio',
#   'WeVenture',
#   'Just Analytics',
#   'DLV Roofing & Exteriors',
#   'Antsomi',
#   'Meete.co',
#   'Miti (Vietnam)',
#   'FPT Software',
#   'Kyanon Digital',
#   'The Coca-Cola Company',
#   'Knorex',
#   'Tiki.vn'],
#  'Job': ['Data Analyst - Monthly',
#   'Data Analyst - Monthly',
#   'Data Analyst - Monthly',
#   'Data Analyst - Monthly',
#   'Data Analyst - Monthly Intern',
#   'Data Analyst - Monthly',
#   'Data Analyst - Monthly',
#   'Data Analyst - Monthly',
#   'Data Analyst - Monthly Intern',
#   'Data Analyst - Monthly',
#   'Data Analyst - Monthly Intern',
#   'Data Analyst - Monthly',
#   'Data Analyst',
#   'Data Analyst - Monthly Intern',
#   'Data Analyst - Monthly',
#   'Data Analyst - Monthly Intern',
#   'Data Analyst - Monthly',
#   'Data Analyst - Monthly',
#   'Data Analyst - Monthly',
#   'Data Analyst - Intern',
#   'Data Analyst - Monthly Intern',
#   'Data Analyst',
#   'Data Analyst - Monthly',
#   'Data Analyst - Monthly',
#   'Data Analyst - Monthly Intern',
#   'Data Analyst - Monthly Intern',
#   'Data Analyst - Monthly',
#   'Data Analyst - Monthly',
#   'Data Analyst - Monthly Intern',
#   'Data Analyst - Monthly',
#   'Data Analyst - Monthly',
#   'Data Analyst - Monthly',
#   'Data Analyst - Monthly',
#   'Data Analyst - Monthly',
#   'Data Analyst - Monthly Intern',
#   'Data Analyst - Monthly',
#   'Data Analyst - Monthly',
#   'Data Analyst',
#   'Data Analyst',
#   'Data Analyst',
#   'Data Analyst - Monthly',
#   'Data Analyst - Monthly',
#   'Data Analyst - Monthly',
#   'Data Scientist - Monthly',
#   'Data Engineer - Monthly',
#   'Data Engineer - Monthly',
#   'Data Scientist - Monthly',
#   'Senior Data Analyst - Monthly',
#   'Senior Data Analyst - Monthly',
#   'Senior Data Analyst',
#   'Senior Data Analyst - Monthly',
#   'Senior Data Analyst - Monthly',
#   'Junior Data Analyst - Monthly',
#   'Junior Data Analyst - Monthly',
#   'Junior Data Analyst - Monthly',
#   'Junior Data Analyst',
#   'Junior Data Analyst - Monthly',
#   'Data Scientist - Monthly',
#   'Data Scientist - Monthly Intern',
#   'Data Scientist - Monthly',
#   'Data Scientist - Monthly Intern',
#   'Data Scientist - Monthly',
#   'Data Scientist - Monthly',
#   'Data Scientist - Monthly',
#   'Data Scientist - Monthly',
#   'Data Scientist - Monthly',
#   'Data Scientist - Monthly Intern',
#   'Data Scientist',
#   'Data Scientist - Monthly',
#   'Data Scientist - Monthly',
#   'Marketing Data Analyst - Monthly',
#   'Lead Data Analyst - Monthly',
#   'Data Science - Intern',
#   'Data Engineer - Monthly',
#   'Data Engineer - Monthly',
#   'Data Engineer - Monthly',
#   'Data Engineer - Monthly',
#   'Data Engineer - Monthly',
#   'Data Engineer - Monthly',
#   'Data Engineer - Monthly',
#   'Data Engineer - Monthly',
#   'Data Engineer - Monthly',
#   'Junior Data Scientist - Monthly',
#   'Junior Data Scientist - Monthly',
#   'Data Entry Clerk - Monthly',
#   'Associate Data Scientist - Monthly',
#   'Data Specialist - Monthly'],
#  'Salary': ['₫14,500,000',
#   '₫11,000,000',
#   '₫8M',
#   '₫17M',
#   '₫4M',
#   '₫18M',
#   '₫15M',
#   '₫13M',
#   '₫3M',
#   '₫17M',
#   '₫5M',
#   '₫7M',
#   '₫193M',
#   '₫1M',
#   '₫19M',
#   '₫5M',
#   '₫20M',
#   '₫5M',
#   '₫24M',
#   '₫5M',
#   '₫4M',
#   '₫151M',
#   '₫8M',
#   '₫19M',
#   '₫2M',
#   '₫3M',
#   '₫19M',
#   '₫8M',
#   '₫5M',
#   '₫29M',
#   '₫10M',
#   '₫3M',
#   '₫4M',
#   '₫9M',
#   '₫2M',
#   '₫12M',
#   '₫18M',
#   '₫116M',
#   '₫191M',
#   '₫114M',
#   '₫10M',
#   '₫8M',
#   '₫10M',
#   '₫19,550,000',
#   '₫18,000,000',
#   '₫40,000,000',
#   '₫19M',
#   '₫18M',
#   '₫14M',
#   '₫27M',
#   '₫17M',
#   '₫50M',
#   '₫24M',
#   '₫4M',
#   '₫9M',
#   '€43K',
#   '₫24M',
#   '₫24M',
#   '₫7M',
#   '₫19M',
#   '₫8M',
#   '₫53M',
#   '₫92M',
#   '₫23M',
#   '₫19M',
#   '₫13M',
#   '₫10M',
#   '₫10M',
#   '₫10M',
#   '₫22M',
#   '₫17M',
#   '₫24M',
#   '₫14M',
#   '₫29M',
#   '₫22M',
#   '₫19M',
#   '₫14M',
#   '₫12M',
#   '₫29M',
#   '₫15M',
#   '₫10M',
#   '₫9M',
#   '₫17M',
#   '₫15M',
#   '₫8M',
#   '₫18M',
#   '₫14M']}
